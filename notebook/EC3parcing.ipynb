# %%
import pandas as pd
import json
import ast

# %%
df = pd.read_csv('EC3EPD_all.csv')
# Out:
# C:\Users\yu528\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (7,20,27,32,38,43,52,72,73,75,76,80,81,82,85,93,94,95,96,97,104,105,113,114,115,117,118,119,123,125,126,137,138,141,142,143,168,184,187) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
columns = df.columns
for i in columns:
    print (i)
# Out:
# id
# created_on
# created_by
# updated_on
# updated_by
# owner
# open_xpd_uuid
# box_id
# doc
# file_name
# copy_of
# date_of_issue
# date_validity_ends
# externally_verified
# rawtxt_product_components
# rawtxt_lca_details
# rawtxt_data_source
# industry_standards
# category
# also_shown_in
# reviewer
# developer
# verifier
# program_operator
# program_operator_fkey
# document_version
# third_party_verification_url
# digitization_qa
# digitization_qa_notes
# digitization_confirmed_on
# digitization_confirmed
# pcr
# pcr_notes
# warnings
# errors
# failures
# is_failed
# name
# alt_names
# description
# sku
# image
# image_small
# datasheet_link
# product_classes
# product_usage_description
# product_usage_image
# manufacturing_description
# manufacturing_image
# concrete_compressive_strength_28d
# concrete_compressive_strength_other
# concrete_compressive_strength_other_d
# concrete_flexion_strength
# concrete_slump
# concrete_min_slump
# concrete_max_slump
# concrete_w_c_ratio
# ...

# %%
pcr = df[['pcr']].copy()
category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64083 entries, 0 to 64082
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  64083 non-null  object
# dtypes: object(1)
# memory usage: 500.8+ KB

# %%
Comb_category = pd.DataFrame()
print(category.head())
# Out:
#                                             category
# 0  {'id': 'b03dba1dca5b49acb1a5aa4daab546b4', 'cr...
# 1  {'id': 'b03dba1dca5b49acb1a5aa4daab546b4', 'cr...
# 2  {'id': 'b03dba1dca5b49acb1a5aa4daab546b4', 'cr...
# 3  {'id': 'b03dba1dca5b49acb1a5aa4daab546b4', 'cr...
# 4  {'id': 'b03dba1dca5b49acb1a5aa4daab546b4', 'cr...

# %%
count=0
for i in category['category']:

    t1 = ast.literal_eval(i)
    temp =pd.DataFrame(t1, index=[0])
    Comb_category=Comb_category.append(temp,ignore_index = True)
    count=count+1
    if count%1000==1:
        print(count)
print(Comb_category.info())
# Out:
# 1
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
# 34001
# 35001
# 36001
# 37001
# 38001
# 39001
# 40001
# 41001
# 42001
# 43001
# 44001
# 45001
# 46001
# 47001
# 48001
# 49001
# 50001
# 51001
# 52001
# 53001
# 54001
# 55001
# 56001
# 57001
# 58001
# 59001
# 60001
# 61001
# 62001
# 63001
# 64001
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64083 entries, 0 to 64082
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             64083 non-null  object
#  1   created_on                     64083 non-null  object
#  2   updated_on                     64083 non-null  object
#  3   name                           64083 non-null  object
# ...

# %% [markdown]
# Comb_category.head()
# Comb_category.to_csv ('category.csv', index = None)

# %%
manufacturer = df[['manufacturer']].copy()
manufacturer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64083 entries, 0 to 64082
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  63837 non-null  object
# dtypes: object(1)
# memory usage: 500.8+ KB

# %%
Comb_manufacturer = pd.DataFrame()
print(manufacturer.head())
# Out:
#                                         manufacturer
# 0  {'id': 'c3d7d8d1e466457798d8c37c0df44cee', 'cr...
# 1  {'id': 'e328292255404974a9240f1c9f6d7728', 'cr...
# 2  {'id': '97bffa520c454d9bbc53a63bdba3b8e2', 'cr...
# 3  {'id': '97bffa520c454d9bbc53a63bdba3b8e2', 'cr...
# 4  {'id': 'c3d7d8d1e466457798d8c37c0df44cee', 'cr...

# %%
fill_text = "{'id': ' ', 'created_on': ' ', 'updated_on': ' ', 'owner': None, 'address': ' ', 'latitude': ' ', 'longitude': ' ', 'location': {'streetNumber': ' ', 'streetName': ' ', 'municipalitySubdivision': ' ', 'municipality': ' ', 'countrySecondarySubdivision': ' ', 'countryTertiarySubdivision': ' ', 'countrySubdivision': ' ', 'postalCode': '', 'countryCode': ' ', 'country': ' ', 'countryCodeISO3': ' ', 'freeformAddress': ' ', 'countrySubdivisionName': ' '}, 'address_line': ' ', 'admin_district': ' ', 'admin_district2': ' ', 'locality': ' ', 'postal_code': ' ', 'country': ' ', 'name': ' ', 'image': ' ', 'legal_name': ' ', 'alt_names': [' '], 'email_extensions': [' '], 'parent_email_extensions': ' ', 'attachments': ' ', 'jurisdiction': ' ', 'primary_activity_owner': ' ', 'primary_activity_builder': ' ', 'primary_activity_design': ' ', 'primary_activity_manufacturer': ' ', 'primary_activity_operator': ' ', 'primary_activity_verifier': ' ', 'primary_activity_industry_association': ' ', 'primary_activity_other': ' ', 'primary_activity_forest_practices_certification': ' ', 'primary_activity_digitization_qa': ' ', 'primary_activity_sustainability_consulting': ' ', 'primary_activity_performance_standards_issuer': '  ', 'iso9001_certified': ' ', 'iso14001_certified': ' ', 'tax_id': ' ', 'website': ' ', 'transparency_catalog_link': ' ', 'email': ' ', 'invalid_after': ' ', 'org_type': ' ', 'currency': ' ', 'enterprise': ' ', 'parent': ' ', 'gwp_contact': ' ', 'user_group_employees': ' ', 'user_group_collaborators': ' '}"
manufacturer=manufacturer.fillna(fill_text)

# %%
print(manufacturer.iloc[6348])
# Out:
# manufacturer    {'id': ' ', 'created_on': ' ', 'updated_on': '...
# Name: 6348, dtype: object

# %%
count=0
country=[]
for i in manufacturer['manufacturer']:
    t1 = ast.literal_eval(i)
    #print(t1)
    country.append(t1.get("country"))

    count=count+1
    if count%1000==1:
        print(count)

manufacturer_collected= pd.DataFrame({'country':country})
print(country)

manufacturer_collected.head()
# Out:
# 1
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
# 34001
# 35001
# 36001
# 37001
# 38001
# 39001
# 40001
# 41001
# 42001
# 43001
# 44001
# 45001
# 46001
# 47001
# 48001
# 49001
# 50001
# 51001
# 52001
# 53001
# 54001
# 55001
# 56001
# 57001
# 58001
# 59001
# 60001
# 61001
# 62001
# 63001
# 64001
# ...

# %%
count=0
latitude=[]
for i in manufacturer['manufacturer']:
    t1 = ast.literal_eval(i)
    #print(t1)
    latitude.append(t1.get('latitude'))

    count=count+1
    if count%1000==1:
        print(count)

manufacturer_latitude= pd.DataFrame({'latitude':latitude})
print(latitude)

manufacturer_collected['latitude']=latitude
count=0manufacturer_collected.describe()
# Out:
# 1
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
# 34001
# 35001
# 36001
# 37001
# 38001
# 39001
# 40001
# 41001
# 42001
# 43001
# 44001
# 45001
# 46001
# 47001
# 48001
# 49001
# 50001
# 51001
# 52001
# 53001
# 54001
# 55001
# 56001
# 57001
# 58001
# 59001
# 60001
# 61001
# 62001
# 63001
# 64001
# ...

# %%
count=0
longitude=[]
for i in manufacturer['manufacturer']:
    t1 = ast.literal_eval(i)
    #print(t1)
    longitude.append(t1.get('longitude'))

    count=count+1
    if count%1000==1:
        print(count)

manufacturer_collected['longitude']=longitude
manufacturer_collected.describe()
# Out:
# 1
# 1001
# 2001
# 3001
# 4001
# 5001
# 6001
# 7001
# 8001
# 9001
# 10001
# 11001
# 12001
# 13001
# 14001
# 15001
# 16001
# 17001
# 18001
# 19001
# 20001
# 21001
# 22001
# 23001
# 24001
# 25001
# 26001
# 27001
# 28001
# 29001
# 30001
# 31001
# 32001
# 33001
# 34001
# 35001
# 36001
# 37001
# 38001
# 39001
# 40001
# 41001
# 42001
# 43001
# 44001
# 45001
# 46001
# 47001
# 48001
# 49001
# 50001
# 51001
# 52001
# 53001
# 54001
# 55001
# 56001
# 57001
# 58001
# 59001
# 60001
# 61001
# 62001
# 63001
# 64001
#        country     latitude    longitude
# count    61708  61708.00000  61708.00000
# unique      41    283.00000    283.00000
# top         US     37.34156   -121.91509
# freq     56785  27354.00000  27354.00000

# %%
manufacturer_collected.to_csv ('manufacturer_collected.csv', index = None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fa95623a76c4> in <module>
# ----> 1 manufacturer_collected.to_csv ('manufacturer_collected.csv', index = None)
#
# NameError: name 'manufacturer_collected' is not defined

# %%
df1 = pd.read_csv('category.csv')
df1.head()
# Out:
#                                  id                   created_on  \
# 0  b03dba1dca5b49acb1a5aa4daab546b4  2018-06-26T01:11:48.938840Z
# 1  b03dba1dca5b49acb1a5aa4daab546b4  2018-06-26T01:11:48.938840Z
# 2  b03dba1dca5b49acb1a5aa4daab546b4  2018-06-26T01:11:48.938840Z
# 3  b03dba1dca5b49acb1a5aa4daab546b4  2018-06-26T01:11:48.938840Z
# 4  b03dba1dca5b49acb1a5aa4daab546b4  2018-06-26T01:11:48.938840Z
#
#                     updated_on      name display_name short_name  \
# 0  2021-01-25T07:00:57.788768Z  ReadyMix     ReadyMix   ReadyMix
# 1  2021-01-25T07:00:57.788768Z  ReadyMix     ReadyMix   ReadyMix
# 2  2021-01-25T07:00:57.788768Z  ReadyMix     ReadyMix   ReadyMix
# 3  2021-01-25T07:00:57.788768Z  ReadyMix     ReadyMix   ReadyMix
# 4  2021-01-25T07:00:57.788768Z  ReadyMix     ReadyMix   ReadyMix
#
#                       masterformat      unspsc  \
# 0  03 30 00 Cast-in-Place Concrete  30111505.0
# 1  03 30 00 Cast-in-Place Concrete  30111505.0
# ...

# %%
df2 = pd.read_csv('manufacturer_collected.csv')
df2.head()
# Out:
#   country  latitude   longitude
# 0      US  37.34156  -121.91509
# 1      US  47.67849  -122.12501
# 2      US  29.78644   -95.54586
# 3      US  29.78644   -95.54586
# 4      US  37.34156  -121.91509

# %%
tempdf = [df[['id','warnings']],df1[["name","declared_unit"]],df2[["country","latitude",'longitude']],df[['density','gwp','gwp_per_category_declared_unit','gwp_per_kg','biogenic_embodied_carbon','use_stored_carbon','stored_carbon']],
          df[['concrete_compressive_strength_28d',
'concrete_compressive_strength_other',
'concrete_compressive_strength_other_d',
'concrete_flexion_strength',
'concrete_slump',
'concrete_min_slump',
'concrete_max_slump',
'concrete_w_c_ratio',
'concrete_aggregate_size_max',
'concrete_min_pipeline_size',
'cementitious',
'concrete_air_entrain',
'concrete_co2_entrain',
'concrete_pervious',
'concrete_self_consolidating',
'white_cement',
'lightweight',
'fiber_reinforced',
'aerated_concrete',
'aci_exposure_classes',
'csa_exposure_classes',
'en_exposure_classes',
'density',
'steel_ultim_tensile_str_min',
'steel_yield_tensile_str_min',
'steel_bar_elongation_min',
'steel_ultim_tensile_str',
'steel_yield_tensile_str',
'steel_bar_elongation',
'steel_recycled_content',
'steel_post_consumer_recycled_content',
'steel_astm_marking',
'steel_euro_marking',
'steel_rebar_diameter_min',
'steel_rebar_bending_pin_max',
'steel_rebar_ts_ys_ratio_max',
'steel_rebar_grade',
'steel_modulus_of_elasticity',
'steel_thermal_expansion',
'steel_thermal_conductivity',
'cold_finished',
'galvanized',
'stainless',
'epoxy_coated',
'gypsum_fire_rating',
'gypsum_thickness',
'specific_density',
'gypsum_specific_density',
'gypsum_r_factor',
'gypsum_flame_spread_astm_e84',
'gypsum_smoke_production_astm_e84',
'gypsum_surface_abrasion_d4977',
'gypsum_indentation_d5420',
'gypsum_soft_body_impact_e695',
'gypsum_hard_body_impact_c1929',
'timber_species',
'fabrication',
'weather_exposed',
'fire_retardant',
'decay_resistant',
'max_size',
'specific_gravity',
'reference_service_life',
'intended_application',
'insulation_intended_application',
'manufacture_type',
'form_factor',
'yarn_weight',
'yarn_type',
'fire_radiant_panel_rating_astme648',
'fire_smoke_density_rating_astme648',
'voc_emissions',
'thickness',
'surface_area',
'insulating_material',
'thickness_per_declared_unit',
'foam_type',
'cushioned',
'bleachable',
'width',
'height',
'recycled_content',
'cladding_r_value',
'cladding_insulating_material',
'cladding_facing_material',
'masonry_white_cement',
'ceiling_panel_core_material',
'ceiling_panel_nrc',
'ceiling_panel_cac',
'cabling_category',
'fire_rating',
'jacket_material',
'outdoor']]]

# %%
df_all = pd.concat(tempdf, axis=1)
df_all.head()
# Out:
#                                  id  \
# 0  d58a88bc8dac40d09fc8b47ff94a552d
# 1  450616bd9e8248f093af2193128b5518
# 2  b128ee9bba70486a9a1b655a5f224982
# 3  1c6572909a9d4eaea56b10af083c3a45
# 4  a0d3434b42344134a681f27682344a11
#
#                                             warnings      name declared_unit  \
# 0  {'pcr': ['EPD issued after PCR expiry date. Ch...  ReadyMix          1 m3
# 1  {'concrete_cement_content': ['Not specified'],...  ReadyMix          1 m3
# 2  {'concrete_cement_content': ['Not specified'],...  ReadyMix          1 m3
# 3  {'concrete_cement_content': ['Not specified'],...  ReadyMix          1 m3
# 4          {'concrete_w_c_ratio': ['Not specified']}  ReadyMix          1 m3
#
#   country  latitude   longitude       density           gwp  \
# 0      US  37.34156  -121.91509  2400.0 kg/m³  339.0 kgCO2e
# 1      US  47.67849  -122.12501  2400.0 kg/m³  339.0 kgCO2e
# 2      US  29.78644   -95.54586  2400.0 kg/m³  296.0 kgCO2e
# ...

# %%
df_all=df_all.drop_duplicates(subset ="id",
                     keep = "first")

# %%
df_all.info()
df_all.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44083 entries, 0 to 64082
# Columns: 107 entries, id to outdoor
# dtypes: float64(53), object(54)
# memory usage: 36.3+ MB
#                                  id  \
# 0  d58a88bc8dac40d09fc8b47ff94a552d
# 1  450616bd9e8248f093af2193128b5518
# 2  b128ee9bba70486a9a1b655a5f224982
# 3  1c6572909a9d4eaea56b10af083c3a45
# 4  a0d3434b42344134a681f27682344a11
#
#                                             warnings      name declared_unit  \
# 0  {'pcr': ['EPD issued after PCR expiry date. Ch...  ReadyMix          1 m3
# 1  {'concrete_cement_content': ['Not specified'],...  ReadyMix          1 m3
# 2  {'concrete_cement_content': ['Not specified'],...  ReadyMix          1 m3
# 3  {'concrete_cement_content': ['Not specified'],...  ReadyMix          1 m3
# 4          {'concrete_w_c_ratio': ['Not specified']}  ReadyMix          1 m3
#
#   country  latitude   longitude       density           gwp  \
# ...

# %%
df_all.to_csv('selectedEC3_0418.csv')
